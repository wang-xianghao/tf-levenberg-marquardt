# %% [markdown]
# <a href="https://colab.research.google.com/github/wang-xianghao/tf-levenberg-marquardt/blob/main/tf-levenberg-marquardt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup Levenberg-Marquardt
# ### Install dependencies from GitHub

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

os.chdir("/content")

lm_dir = "tf-levenberg-marquardt"
if not os.path.exists(lm_dir):
  # !git clone https://github.com/fabiodimarco/$lm_dir

os.chdir(lm_dir)

# !pip install pip install tensorflow==2.15.0

# %% [markdown]
# # Test curve fitting
#
# The function `y = sinc(10 * x)` is fitted using a Shallow Neural Network with 61 parameters.
# Despite the triviality of the problem, first-order methods such as Adam fail to converge, while Levenberg–Marquardt converges rapidly with very low loss values. The values of learning_rate were chosen experimentally on the basis of the results obtained by each algorithm.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import levenberg_marquardt as lm

input_size = 20000
batch_size = 1000

x_train = np.linspace(-1, 1, input_size, dtype=np.float64)
y_train = np.sinc(10 * x_train)

x_train = tf.expand_dims(tf.cast(x_train, tf.float32), axis=-1)
y_train = tf.expand_dims(tf.cast(y_train, tf.float32), axis=-1)

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(input_size)
train_dataset = train_dataset.batch(batch_size).cache()
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(20, activation='tanh', input_shape=(1,)),
    tf.keras.layers.Dense(1, activation='linear')])

model.summary()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
    loss=tf.keras.losses.MeanSquaredError())

model_wrapper = lm.ModelWrapper(
    tf.keras.models.clone_model(model))

model_wrapper.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=1.0),
    loss=lm.MeanSquaredError())

print("Train using Adam")
t1_start = time.perf_counter()
model.fit(train_dataset, epochs=1000)
t1_stop = time.perf_counter()
print("Elapsed time: ", t1_stop - t1_start)

print("\n_________________________________________________________________")
print("Train using Levenberg-Marquardt")
t2_start = time.perf_counter()
model_wrapper.fit(train_dataset, epochs=100)
t2_stop = time.perf_counter()
print("Elapsed time: ", t2_stop - t2_start)

print("\n_________________________________________________________________")
print("Plot results")
plt.plot(x_train, y_train, 'b-', label="reference")
plt.plot(x_train, model.predict(x_train), 'g--', label="adam")
plt.plot(x_train, model_wrapper.predict(x_train), 'r--', label="lm")
plt.legend()
plt.show()
# Out:
# _________________________________________________________________
# Train using Levenberg-Marquardt
# Epoch 1/100
# WARNING:tensorflow:5 out of the last 3193 calls to <function _BaseOptimizer._update_step_xla at 0x78dfe7bd55a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 20/20 [==============================] - 3s 100ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 0.0235
# Epoch 2/100
# 20/20 [==============================] - 3s 130ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 0.0029
# Epoch 3/100
# 20/20 [==============================] - 3s 134ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 0.0022
# Epoch 4/100
# 20/20 [==============================] - 4s 196ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 0.0016
# Epoch 5/100
# 20/20 [==============================] - 3s 135ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 0.0014
# Epoch 6/100
# 20/20 [==============================] - 3s 149ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 8.7474e-04
# Epoch 7/100
# 20/20 [==============================] - 2s 86ms/step - damping_factor: 1.0000e-05 - attempts: 3.0000 - loss: 5.8223e-04
# Epoch 8/100
# 20/20 [==============================] - 1s 65ms/step - damping_factor: 1.0000e-05 - attempts: 3.0000 - loss: 4.8197e-04
# Epoch 9/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 4.5418e-04
# Epoch 10/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 4.3316e-04
# Epoch 11/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 4.1294e-04
# Epoch 12/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 3.8212e-04
# Epoch 13/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 3.4547e-04
# Epoch 14/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 3.2051e-04
# Epoch 15/100
# 20/20 [==============================] - 1s 69ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 3.0694e-04
# Epoch 16/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 2.9365e-04
# Epoch 17/100
# 20/20 [==============================] - 1s 64ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 2.7804e-04
# Epoch 18/100
# 20/20 [==============================] - 1s 64ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 2.6049e-04
# Epoch 19/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 2.4604e-04
# Epoch 20/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 2.3010e-04
# Epoch 21/100
# 20/20 [==============================] - 1s 64ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 2.0765e-04
# Epoch 22/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 1.7734e-04
# Epoch 23/100
# 20/20 [==============================] - 1s 65ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 1.4170e-04
# Epoch 24/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 1.2735e-04
# Epoch 25/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 1.1364e-04
# Epoch 26/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 9.7161e-05
# Epoch 27/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 8.0755e-05
# Epoch 28/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 6.4861e-05
# Epoch 29/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 5.0075e-05
# Epoch 30/100
# 20/20 [==============================] - 1s 59ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 3.5266e-05
# Epoch 31/100
# 20/20 [==============================] - 2s 84ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 2.2802e-05
# Epoch 32/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-05 - attempts: 2.0000 - loss: 1.6824e-05
# Epoch 33/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.2783e-05
# Epoch 34/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 8.6628e-06
# Epoch 35/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 7.6230e-06
# Epoch 36/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 6.9859e-06
# Epoch 37/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 6.4956e-06
# Epoch 38/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 6.0904e-06
# Epoch 39/100
# 20/20 [==============================] - 1s 71ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 5.7474e-06
# Epoch 40/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 5.4501e-06
# Epoch 41/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 5.1881e-06
# Epoch 42/100
# 20/20 [==============================] - 1s 64ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 4.9537e-06
# Epoch 43/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 4.7450e-06
# Epoch 44/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 4.5509e-06
# Epoch 45/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 4.3715e-06
# Epoch 46/100
# 20/20 [==============================] - 1s 65ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 4.1747e-06
# Epoch 47/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 3.9886e-06
# Epoch 48/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 3.8317e-06
# Epoch 49/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 3.6482e-06
# Epoch 50/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 3.4988e-06
# Epoch 51/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 3.3518e-06
# Epoch 52/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 3.2079e-06
# Epoch 53/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 3.0581e-06
# Epoch 54/100
# 20/20 [==============================] - 2s 85ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 2.8781e-06
# Epoch 55/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 2.7050e-06
# Epoch 56/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 2.5853e-06
# Epoch 57/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 2.4710e-06
# Epoch 58/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 2.3677e-06
# Epoch 59/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 2.2709e-06
# Epoch 60/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 2.1805e-06
# Epoch 61/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 2.0794e-06
# Epoch 62/100
# 20/20 [==============================] - 1s 73ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.9904e-06
# Epoch 63/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.9219e-06
# Epoch 64/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.8328e-06
# Epoch 65/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.7727e-06
# Epoch 66/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.7109e-06
# Epoch 67/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.6437e-06
# Epoch 68/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.5893e-06
# Epoch 69/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.5384e-06
# Epoch 70/100
# 20/20 [==============================] - 1s 66ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.4700e-06
# Epoch 71/100
# 20/20 [==============================] - 1s 59ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.4312e-06
# Epoch 72/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.3916e-06
# Epoch 73/100
# 20/20 [==============================] - 1s 65ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.3419e-06
# Epoch 74/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.3092e-06
# Epoch 75/100
# 20/20 [==============================] - 1s 59ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.2724e-06
# Epoch 76/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.2364e-06
# Epoch 77/100
# 20/20 [==============================] - 1s 63ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.2007e-06
# Epoch 78/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.1738e-06
# Epoch 79/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.1310e-06
# Epoch 80/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.1043e-06
# Epoch 81/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.0795e-06
# Epoch 82/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.0550e-06
# Epoch 83/100
# 20/20 [==============================] - 1s 59ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 1.0121e-06
# Epoch 84/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 9.6140e-07
# Epoch 85/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 9.3097e-07
# Epoch 86/100
# 20/20 [==============================] - 2s 83ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 9.0598e-07
# Epoch 87/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 8.7602e-07
# Epoch 88/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 8.3715e-07
# Epoch 89/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 8.0278e-07
# Epoch 90/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 7.7415e-07
# Epoch 91/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 7.4593e-07
# Epoch 92/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 7.1587e-07
# Epoch 93/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 6.8111e-07
# Epoch 94/100
# 20/20 [==============================] - 1s 66ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 6.5245e-07
# Epoch 95/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 6.2566e-07
# Epoch 96/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 5.8803e-07
# Epoch 97/100
# 20/20 [==============================] - 1s 60ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 5.6295e-07
# Epoch 98/100
# 20/20 [==============================] - 1s 62ms/step - damping_factor: 1.0000e-06 - attempts: 3.0000 - loss: 5.4204e-07
# Epoch 99/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 5.1012e-07
# Epoch 100/100
# 20/20 [==============================] - 1s 61ms/step - damping_factor: 1.0000e-06 - attempts: 2.0000 - loss: 4.8230e-07
# Elapsed time:  160.524631934
#
# _________________________________________________________________
# Plot results
# 625/625 [==============================] - 2s 3ms/step

# %% [markdown]
# # Test mnist classification
#
# The classification is performed using a Convolutional Neural Network with 1026 parameters.
# This time there were no particular benefits as in the previous case. Even if Levenberg–Marquardt converges with far fewer epochs than Adam, the longer execution time per step nullifies its advantages.
# However, both methods achieve roughly the same accuracy values on train and test set.

# %%
import tensorflow as tf
import time
import levenberg_marquardt as lm

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = tf.cast(x_train / 255.0, dtype=tf.float32)
x_test = tf.cast(x_test / 255.0, dtype=tf.float32)

x_train = tf.expand_dims(x_train, axis=-1)
x_test = tf.expand_dims(x_test, axis=-1)

y_train = tf.cast(y_train, dtype=tf.float32)
y_test = tf.cast(y_test, dtype=tf.float32)

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(60000)
train_dataset = train_dataset.batch(6000).cache()
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=8, kernel_size=4, strides=2, padding='valid',
                           activation='tanh', input_shape=(28, 28, 1)),
    tf.keras.layers.Conv2D(filters=4, kernel_size=4, strides=2, padding='valid',
                           activation='tanh'),
    tf.keras.layers.Conv2D(filters=4, kernel_size=2, strides=1, padding='valid',
                           activation='tanh'),
    tf.keras.layers.Conv2D(filters=4, kernel_size=2, strides=1, padding='valid',
                           activation='tanh'),
    tf.keras.layers.Conv2D(filters=4, kernel_size=2, strides=1, padding='valid',
                           activation='tanh'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='linear')
])

model.summary()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"])

model_wrapper = lm.ModelWrapper(tf.keras.models.clone_model(model))

model_wrapper.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.1),
    loss=lm.SparseCategoricalCrossentropy(from_logits=True),
    solve_method='solve',
    metrics=['accuracy'])

print("Train using Adam")
t1_start = time.perf_counter()
model.fit(train_dataset, epochs=200)
t1_stop = time.perf_counter()
print("Elapsed time: ", t1_stop - t1_start)

print("\n_________________________________________________________________")
print("Train using Levenberg-Marquardt")
t2_start = time.perf_counter()
model_wrapper.fit(train_dataset, epochs=10)
t2_stop = time.perf_counter()
print("Elapsed time: ", t2_stop - t2_start)

print("\n_________________________________________________________________")
print("Test set results")

test_loss, test_acc = model.evaluate(x=x_test, y=y_test, verbose=0)
print("adam - test_loss: %f - test_accuracy: %f" % (test_loss, test_acc))

test_loss, test_acc = model_wrapper.evaluate(x=x_test, y=y_test, verbose=0)
print("lm - test_loss: %f - test_accuracy: %f" % (test_loss, test_acc))
